# %%
# Imports
# !pip install torchinfo
import torch
import torch.nn as nn
import torch.utils.data as Data
from torchinfo import summary
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import time
import Trainer_v03b1 as TP

# %% [markdown]
# ## Network structures

# %%
m1 = TP.ImageEncoder()
summary(m1, input_size=(1, 1, 128, 128))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ImageEncoder                             [1, 256]                  --
# ├─Sequential: 1-1                        [1, 16, 64, 64]           --
# │    └─Conv2d: 2-1                       [1, 16, 64, 64]           160
# │    └─Identity: 2-2                     [1, 16, 64, 64]           --
# │    └─LeakyReLU: 2-3                    [1, 16, 64, 64]           --
# ├─Sequential: 1-2                        [1, 32, 32, 32]           --
# │    └─Conv2d: 2-4                       [1, 32, 32, 32]           4,640
# │    └─Identity: 2-5                     [1, 32, 32, 32]           --
# │    └─LeakyReLU: 2-6                    [1, 32, 32, 32]           --
# ├─Sequential: 1-3                        [1, 64, 16, 16]           --
# │    └─Conv2d: 2-7                       [1, 64, 16, 16]           18,496
# │    └─Identity: 2-8                     [1, 64, 16, 16]           --
# │    └─LeakyReLU: 2-9                    [1, 64, 16, 16]           --
# ├─Sequential: 1-4                        [1, 128, 8, 8]            --
# │    └─Conv2d: 2-10                      [1, 128, 8, 8]            73,856
# │    └─Identity: 2-11                    [1, 128, 8, 8]            --
# │    └─LeakyReLU: 2-12                   [1, 128, 8, 8]            --
# ├─Sequential: 1-5                        [1, 256, 4, 4]            --
# │    └─Conv2d: 2-13                      [1, 256, 4, 4]            295,168
# │    └─Identity: 2-14                    [1, 256, 4, 4]            --
# │    └─LeakyReLU: 2-15                   [1, 256, 4, 4]            --
# ├─Sequential: 1-6                        [1, 256]                  --
# │    └─Linear: 2-16                      [1, 4096]                 16,781,312
# │    └─ReLU: 2-17                        [1, 4096]                 --
# │    └─Linear: 2-18                      [1, 256]                  1,048,832
# │    └─Sigmoid: 2-19                     [1, 256]                  --
# ==========================================================================================
# Total params: 18,222,464
# Trainable params: 18,222,464
# Non-trainable params: 0
# Total mult-adds (M): 37.42
# ==========================================================================================
# Input size (MB): 0.07
# Forward/backward pass size (MB): 1.05
# Params size (MB): 72.89
# Estimated Total Size (MB): 74.01
# ==========================================================================================

# %%
m2 = TP.ImageDecoder()
summary(m2, input_size=(1, 256))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/torchinfo/torchinfo.py in forward_pass(model, x, batch_dim, cache_forward_pass, device, mode, **kwargs)
#     294             if isinstance(x, (list, tuple)):
# --> 295                 _ = model(*x, **kwargs)
#     296             elif isinstance(x, dict):
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1119
# -> 1120         result = forward_call(*input, **kwargs)
#    1121         if _global_forward_hooks or self._forward_hooks:
#
# ~/datastore/CSI-Imaging/Trainer_v03b1.py in forward(self, x)
#     169         x = self.fclayers(x.view(-1, 256))
# --> 170         x = self.layer1(x.view(-1, 1, 16, 16))
#     171         x = self.layer2(x)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1119
# -> 1120         result = forward_call(*input, **kwargs)
#    1121         if _global_forward_hooks or self._forward_hooks:
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1119
# -> 1120         result = forward_call(*input, **kwargs)
#    1121         if _global_forward_hooks or self._forward_hooks:
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input, output_size)
#     924             input, self.weight, self.bias, self.stride, self.padding,
# --> 925             output_padding, self.groups, self.dilation)
#     926
#
# RuntimeError: Given transposed=1, weight of size [256, 128, 4, 4], expected input[1, 1, 16, 16] to have 256 channels, but got 1 channels instead
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_4837/1875978486.py in <module>
#       1 m2 = TP.ImageDecoder()
# ----> 2 summary(m2, input_size=(1, 256))
#
# ~/.local/lib/python3.7/site-packages/torchinfo/torchinfo.py in summary(model, input_size, input_data, batch_dim, cache_forward_pass, col_names, col_width, depth, device, dtypes, mode, row_settings, verbose, **kwargs)
#     222     )
#     223     summary_list = forward_pass(
# --> 224         model, x, batch_dim, cache_forward_pass, device, model_mode, **kwargs
#     225     )
#     226     formatting = FormattingOptions(depth, verbose, columns, col_width, rows)
#
# ~/.local/lib/python3.7/site-packages/torchinfo/torchinfo.py in forward_pass(model, x, batch_dim, cache_forward_pass, device, mode, **kwargs)
#     305             "Failed to run torchinfo. See above stack traces for more details. "
#     306             f"Executed layers up to: {executed_layers}"
# --> 307         ) from e
#     308     finally:
#     309         if hooks:
#
# RuntimeError: Failed to run torchinfo. See above stack traces for more details. Executed layers up to: [Sequential: 1, Linear: 2, ReLU: 2, Linear: 2, ReLU: 2]

# %%
m3 =TP.CsiEncoder()
summary(m3, input_size=(2, 90, 100))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CsiEncoder                               [1, 256]                  353,374,464
# ├─Sequential: 1-1                        [1, 16, 30, 98]           --
# │    └─Conv2d: 2-1                       [1, 16, 30, 98]           160
# │    └─LeakyReLU: 2-2                    [1, 16, 30, 98]           --
# ├─Sequential: 1-2                        [1, 32, 14, 48]           --
# │    └─Conv2d: 2-3                       [1, 32, 14, 48]           4,640
# │    └─LeakyReLU: 2-4                    [1, 32, 14, 48]           --
# ├─Sequential: 1-3                        [1, 64, 12, 46]           --
# │    └─Conv2d: 2-5                       [1, 64, 12, 46]           18,496
# │    └─LeakyReLU: 2-6                    [1, 64, 12, 46]           --
# ├─Sequential: 1-4                        [1, 128, 10, 44]          --
# │    └─Conv2d: 2-7                       [1, 128, 10, 44]          73,856
# │    └─LeakyReLU: 2-8                    [1, 128, 10, 44]          --
# ├─Sequential: 1-5                        [1, 256, 8, 42]           --
# │    └─Conv2d: 2-9                       [1, 256, 8, 42]           295,168
# │    └─LeakyReLU: 2-10                   [1, 256, 8, 42]           --
# ├─Sequential: 1-6                        [1, 16, 30, 98]           (recursive)
# │    └─Conv2d: 2-11                      [1, 16, 30, 98]           (recursive)
# │    └─LeakyReLU: 2-12                   [1, 16, 30, 98]           --
# ├─Sequential: 1-7                        [1, 32, 14, 48]           (recursive)
# │    └─Conv2d: 2-13                      [1, 32, 14, 48]           (recursive)
# │    └─LeakyReLU: 2-14                   [1, 32, 14, 48]           --
# ├─Sequential: 1-8                        [1, 64, 12, 46]           (recursive)
# │    └─Conv2d: 2-15                      [1, 64, 12, 46]           (recursive)
# │    └─LeakyReLU: 2-16                   [1, 64, 12, 46]           --
# ├─Sequential: 1-9                        [1, 128, 10, 44]          (recursive)
# │    └─Conv2d: 2-17                      [1, 128, 10, 44]          (recursive)
# │    └─LeakyReLU: 2-18                   [1, 128, 10, 44]          --
# ├─Sequential: 1-10                       [1, 256, 8, 42]           (recursive)
# │    └─Conv2d: 2-19                      [1, 256, 8, 42]           (recursive)
# │    └─LeakyReLU: 2-20                   [1, 256, 8, 42]           --
# ├─Sequential: 1-11                       --                        --
# │    └─LSTM: 2-21                        [1, 336, 256]             1,314,816
# ==========================================================================================
# Total params: 355,081,600
# Trainable params: 355,081,600
# Non-trainable params: 0
# Total mult-adds (M): 732.72
# ==========================================================================================
# Input size (MB): 0.07
# Forward/backward pass size (MB): 2.66
# Params size (MB): 6.83
# Estimated Total Size (MB): 9.56
# ==========================================================================================

# %% [markdown]
# ## Loader

# %%
transform = transforms.Compose([transforms.Resize([128,128]),
                                transforms.ToTensor(),
                           #     transforms.Normalize((0.5, ), (0.5, ))
])

data_train = datasets.MNIST(root = "../Dataset/MNIST/",
                            transform=transform,
                            train = True,
                            download = True)

data_test = datasets.MNIST(root="../Dataset/MNIST/",
                           transform = transform,
                           train = False)

train_loader = torch.utils.data.DataLoader(dataset=data_train,
                                           batch_size = 64,
                                           shuffle = True,
                                          drop_last=True)

valid_loader = train_loader

test_loader = torch.utils.data.DataLoader(dataset=data_test,
                                          batch_size = 64,
                                          drop_last=True,
                                          shuffle = True)

# %%
# Hyperparameters
t_args = TP.MyArgs(cuda=0, epochs=30, learning_rate=1e-5, criterion=nn.SmoothL1Loss())
s_args = TP.MyArgs(cuda=0, epochs=100, learning_rate=1e-5, criterion=nn.SmoothL1Loss())

# %%
# Model and Loss
imgencoder = TP.ImageEncoder(batchnorm=False, latent_dim=256).to(t_args.device)
imgdecoder = TP.ImageDecoder(latent_dim=256, active_func=nn.LeakyReLU(inplace=True)).to(t_args.device)
csiencoder = TP.CsiEncoder(batchnorm=False, latent_dim=256).to(t_args.device)
optimizer = torch.optim.Adam

trainer = TP.TrainerTS(imgencoder, imgdecoder, csiencoder,
                                   t_args, s_args, 
                                   train_loader, valid_loader, test_loader,
                                   optimizer, temperature=1)

# %%
# Load from checkpoints
trainer.toal_epochs=0
imgencoder.load_state_dict(torch.load('../Models/ImgEn_Model_v02a1_ImgEn_Fc_0307_tep1200.pth'))
imgdecoder.load_state_dict(torch.load('../Models/ImgDe_Model_v02a1_ImgDe_FC_0307_tep1200.pth'))
csiencoder.load_state_dict(torch.load('../Models/CSIEn_Model_v02a1_CsiEn_Last_0307_tep1200_sep700.pth'))
# Out:
# <All keys matched successfully>

# %%
# When changing learning rate
t_args = TP.MyArgs(cuda=1, epochs=100, learning_rate=1e-6, criterion=nn.SmoothL1Loss())
s_args = TP.MyArgs(cuda=1, epochs=100, learning_rate=1e-7, criterion=nn.SmoothL1Loss())
trainer.teacher_args = t_args
trainer.student_args = s_args

# %%
# Training and Saving
trainer.train_teacher()
# Out:
# Teacher: epoch=29/30,936/937of train, loss=0.025483284145593643
# Total training time: 1014.3573791980743 sec

# %%
# Plot loss curves
# %matplotlib inline
trainer.plot_teacher_loss()

# %%
  #=====================test============================
trainer.test_teacher(mode='train')
# Out:
# Teacher: 930/937of test, loss=0.028559537604451184

# %%
# %matplotlib inline
trainer.plot_teacher_test()

# %%
# Training and Saving
trainer.train_student()

# %%
# Plot loss curves
# %matplotlib inline
trainer.plot_student_loss()

# %%
  #=====================test============================
trainer.test_student()
# Out:
# Student: 612/765of test, student loss=0.00014511118934024125, distill loss=-5.546392440795898, image loss=26.167846679687581

# %%
# Final outputs
# %matplotlib inline
trainer.plot_student_test()

# %%
notion = '_0307'
torch.save(trainer.csi_encoder.state_dict(),
           '../Models/CSIEn_' + str(trainer.csi_encoder) + notion + '_tep' + str(trainer.teacher_epochs) +
           '_sep' + str(trainer.student_epochs) + '.pth')

# %%
print(trainer.teacher_args.learning_rate)
# Out:
# 1e-06
